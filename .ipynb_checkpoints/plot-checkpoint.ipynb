# %%
import numpy as np
from numpy import linalg as LA
import scipy.linalg as la
from scipy.sparse.linalg import eigsh, eigs, expm_multiply
from scipy.linalg import expm
import matplotlib.pyplot as plt
import multiprocessing as mp
import random, math
from scipy import stats
import operator
from scipy.optimize import curve_fit 
from matplotlib.colors import LogNorm
from scipy.interpolate import interp2d
from scipy.interpolate import interp1d
from scipy.interpolate import griddata  # Import the griddata function
from scipy import interpolate
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from matplotlib import colors
from matplotlib import rc
rc('text',usetex=True)
import matplotlib.ticker as tick
from matplotlib import cm
from matplotlib.colors import Normalize

# %%
Eloc00 = np.load("Eloc_temperature=0.0.npy", allow_pickle=True)
mag00 = np.load("mag_temperature=0.0.npy", allow_pickle=True)
varmag00 = np.load("varmag_temperature=0.0.npy", allow_pickle=True)
logprobs00 = np.load("log_probs_temperature=0.0.npy", allow_pickle=True)
Floc00 = np.load("Floc_temperature=0.0.npy", allow_pickle=True)
varFloc00 = np.load("varFloc_temperature=0.0.npy", allow_pickle=True)

Eloc05 = np.load("Eloc_temperature=0.5.npy", allow_pickle=True)
mag05 = np.load("mag_temperature=0.5.npy", allow_pickle=True)
varmag05 = np.load("varmag_temperature=0.5.npy", allow_pickle=True)
logprobs05 = np.load("log_probs_temperature=0.5.npy", allow_pickle=True)
Floc05 = np.load("Floc_temperature=0.5.npy", allow_pickle=True)
varFloc05 = np.load("varFloc_temperature=0.5.npy", allow_pickle=True)

Eloc06 = np.load("Eloc_temperature=0.6.npy", allow_pickle=True)
mag06 = np.load("mag_temperature=0.6.npy", allow_pickle=True)
varmag06 = np.load("varmag_temperature=0.6.npy", allow_pickle=True)
logprobs06 = np.load("log_probs_temperature=0.6.npy", allow_pickle=True)
Floc06 = np.load("Floc_temperature=0.6.npy", allow_pickle=True)
varFloc06 = np.load("varFloc_temperature=0.6.npy", allow_pickle=True)

Eloc07 = np.load("Eloc_temperature=0.7.npy", allow_pickle=True)
mag07 = np.load("mag_temperature=0.7.npy", allow_pickle=True)
varmag07 = np.load("varmag_temperature=0.7.npy", allow_pickle=True)
logprobs07 = np.load("log_probs_temperature=0.7.npy", allow_pickle=True)
Floc07 = np.load("Floc_temperature=0.7.npy", allow_pickle=True)
varFloc07 = np.load("varFloc_temperature=0.7.npy", allow_pickle=True)

Eloc08 = np.load("Eloc_temperature=0.8.npy", allow_pickle=True)
mag08 = np.load("mag_temperature=0.8.npy", allow_pickle=True)
varmag08 = np.load("varmag_temperature=0.8.npy", allow_pickle=True)
logprobs08 = np.load("log_probs_temperature=0.8.npy", allow_pickle=True)
Floc08 = np.load("Floc_temperature=0.8.npy", allow_pickle=True)
varFloc08 = np.load("varFloc_temperature=0.8.npy", allow_pickle=True)

Eloc10 = np.load("Eloc_temperature=1.0.npy", allow_pickle=True)
mag10 = np.load("mag_temperature=1.0.npy", allow_pickle=True)
varmag10 = np.load("varmag_temperature=1.0.npy", allow_pickle=True)
logprobs10 = np.load("log_probs_temperature=1.0.npy", allow_pickle=True)
Floc10 = np.load("Floc_temperature=1.0.npy", allow_pickle=True)
varFloc10 = np.load("varFloc_temperature=1.0.npy", allow_pickle=True)

Eloc15 = np.load("Eloc_temperature=1.5.npy", allow_pickle=True)
mag15 = np.load("mag_temperature=1.5.npy", allow_pickle=True)
varmag15 = np.load("varmag_temperature=1.5.npy", allow_pickle=True)
logprobs15 = np.load("log_probs_temperature=1.5.npy", allow_pickle=True)
Floc15 = np.load("Floc_temperature=1.5.npy", allow_pickle=True)
varFloc15 = np.load("varFloc_temperature=1.5.npy", allow_pickle=True)

Eloc25 = np.load("Eloc_temperature=2.5.npy", allow_pickle=True)
mag25 = np.load("mag_temperature=2.5.npy", allow_pickle=True)
varmag25 = np.load("varmag_temperature=2.5.npy", allow_pickle=True)
logprobs25 = np.load("log_probs_temperature=2.5.npy", allow_pickle=True)
Floc25 = np.load("Floc_temperature=2.5.npy", allow_pickle=True)
varFloc25 = np.load("varFloc_temperature=2.5.npy", allow_pickle=True)

Eloc35 = np.load("Eloc_temperature=3.5.npy", allow_pickle=True)
mag35 = np.load("mag_temperature=3.5.npy", allow_pickle=True)
varmag35 = np.load("varmag_temperature=3.5.npy", allow_pickle=True)
logprobs35 = np.load("log_probs_temperature=3.5.npy", allow_pickle=True)
Floc35 = np.load("Floc_temperature=3.5.npy", allow_pickle=True)
varFloc35 = np.load("varFloc_temperature=3.5.npy", allow_pickle=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 Eloc00 = np.load("Eloc_temperature=0.0.npy", allow_pickle=True)
#       2 mag00 = np.load("mag_temperature=0.0.npy", allow_pickle=True)
#       3 varmag00 = np.load("varmag_temperature=0.0.npy", allow_pickle=True)
#
# File ~/anaconda3/lib/python3.8/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Eloc_temperature=0.0.npy'

# %%
fig, ax1 = plt.subplots()

ax1.plot(mag00, color='red',    linewidth=2, label=r"T=0.0")
ax1.plot(mag05, color='blue',   linewidth=2, label=r"T=0.5")
ax1.plot(mag06, color='green',  linewidth=2, label=r"T=0.6")
ax1.plot(mag07, color='orange', linewidth=2, label=r"T=0.7")
ax1.plot(mag08, color='purple', linewidth=2, label=r"T=0.8")
ax1.plot(mag10, color='brown',  linewidth=2, label=r"T=1.0")
ax1.plot(mag15, color='pink',   linewidth=2, label=r"T=1.5")
ax1.plot(mag25, color='gray',   linewidth=2, label=r"T=2.5")
ax1.plot(mag35, color='olive',  linewidth=2, label=r"T=3.5")


#ax1.set_title(r"theta = 1",fontsize =18,fontweight='bold')
ax1.set_xlabel(r'$epoch$',fontsize =18,fontweight='bold')
ax1.set_ylabel(r'$m^2$',fontsize =18,fontweight='bold')


ax1.tick_params(axis='both', which='major', labelsize=18)
ax1.yaxis.get_offset_text().set_fontsize(18)
ax1.legend(loc='upper right',fontsize=12,ncol=1)

plt.savefig('magnetization_N=20_fully_connected.pdf',bbox_inches="tight")

plt.show()

# %%
fig, ax1 = plt.subplots()

ax1.plot(logprobs00, color='red',    linewidth=2, label=r"T=0.0")
ax1.plot(logprobs05, color='blue',   linewidth=2, label=r"T=0.5")
ax1.plot(logprobs06, color='green',  linewidth=2, label=r"T=0.6")
ax1.plot(logprobs07, color='orange', linewidth=2, label=r"T=0.7")
ax1.plot(logprobs08, color='purple', linewidth=2, label=r"T=0.8")
ax1.plot(logprobs10, color='brown',  linewidth=2, label=r"T=1.0")
ax1.plot(logprobs15, color='pink',   linewidth=2, label=r"T=1.5")
ax1.plot(logprobs25, color='gray',   linewidth=2, label=r"T=2.5")
ax1.plot(logprobs35, color='olive',  linewidth=2, label=r"T=3.5")


#ax1.set_title(r"theta = 1",fontsize =18,fontweight='bold')
ax1.set_xlabel(r'$epoch$',fontsize =18,fontweight='bold')
ax1.set_ylabel(r'$log(P_{\theta})$',fontsize =18,fontweight='bold')


ax1.tick_params(axis='both', which='major', labelsize=18)
ax1.yaxis.get_offset_text().set_fontsize(18)
ax1.legend(loc='upper right',fontsize=12,ncol=1)

plt.savefig('Log_Probs_N=20_fully_connected.pdf',bbox_inches="tight")

plt.show()

# %%
fig, ax1 = plt.subplots()

ax1.plot(Floc00, color='red',    linewidth=2, label=r"T=0.0")
ax1.plot(Floc05, color='blue',   linewidth=2, label=r"T=0.5")
ax1.plot(Floc06, color='green',  linewidth=2, label=r"T=0.6")
ax1.plot(Floc07, color='orange', linewidth=2, label=r"T=0.7")
ax1.plot(Floc08, color='purple', linewidth=2, label=r"T=0.8")
ax1.plot(Floc10, color='brown',  linewidth=2, label=r"T=1.0")
ax1.plot(Floc15, color='pink',   linewidth=2, label=r"T=1.5")
ax1.plot(Floc25, color='gray',   linewidth=2, label=r"T=2.5")
ax1.plot(Floc35, color='olive',  linewidth=2, label=r"T=3.5")


#ax1.set_title(r"theta = 1",fontsize =18,fontweight='bold')
ax1.set_xlabel(r'$epoch$',fontsize =18,fontweight='bold')
ax1.set_ylabel(r'$Free Energy$',fontsize =18,fontweight='bold')


ax1.tick_params(axis='both', which='major', labelsize=18)
ax1.yaxis.get_offset_text().set_fontsize(18)
ax1.legend(loc='upper right',fontsize=12,ncol=1)

plt.savefig('Free_energy_N=20_fully_connected.pdf',bbox_inches="tight")

plt.show()

# %%
fig, ax1 = plt.subplots()

ax1.plot(Eloc00, color='red',    linewidth=2, label=r"T=0.0")
ax1.plot(Eloc05, color='blue',   linewidth=2, label=r"T=0.5")
ax1.plot(Eloc06, color='green',  linewidth=2, label=r"T=0.6")
ax1.plot(Eloc07, color='orange', linewidth=2, label=r"T=0.7")
ax1.plot(Eloc08, color='purple', linewidth=2, label=r"T=0.8")
ax1.plot(Eloc10, color='brown',  linewidth=2, label=r"T=1.0")
ax1.plot(Eloc15, color='pink',   linewidth=2, label=r"T=1.5")
ax1.plot(Eloc25, color='gray',   linewidth=2, label=r"T=2.5")
ax1.plot(Eloc35, color='olive',  linewidth=2, label=r"T=3.5")


#ax1.set_title(r"theta = 1",fontsize =18,fontweight='bold')
ax1.set_xlabel(r'$epoch$',fontsize =18,fontweight='bold')
ax1.set_ylabel(r'$Energy$',fontsize =18,fontweight='bold')


ax1.tick_params(axis='both', which='major', labelsize=18)
ax1.yaxis.get_offset_text().set_fontsize(18)
ax1.legend(loc='upper right',fontsize=12,ncol=1)

plt.savefig('Energy_N=20_fully_connected.pdf',bbox_inches="tight")

plt.show()

# %%
import math

def compute_magnetization(beta, J, h, tol=1e-6, max_iter=1000):
    """
    Compute the magnetization m by solving the self-consistency equation:
        m = tanh(beta * (J*m + h))
    
    Parameters:
        beta (float): Inverse temperature, beta = 1/(k_B*T)
        J (float): Coupling constant
        h (float): External magnetic field
        tol (float): Tolerance for convergence
        max_iter (int): Maximum number of iterations
        
    Returns:
        m (float): Converged magnetization value
    """
    m_old = -0.8  # initial guess
    for iteration in range(max_iter):
        m_new = math.tanh(beta * (J * m_old))
        print("new=",m_new)
        print("old=",m_old)
        if abs(m_new - m_old) < tol:
            print(f"Converged in {iteration+1} iterations.")
            return m_new
        m_old = m_new
    print("Did not converge within the maximum number of iterations.")
    return m_old

# Parameters
T = 
beta = 1/T    # inverse temperature (1/k_B T)
J = 1.0       # coupling constant
h = 0.0       # external field

m = compute_magnetization(beta, J, h)
print(f"The computed magnetization is: {m:.6f}")
# Out:
# new= -0.8336546070121553
# old= -0.8
# new= -0.8484187196004104
# old= -0.8336546070121553
# new= -0.8545083440598783
# old= -0.8484187196004104
# new= -0.8569538006611693
# old= -0.8545083440598783
# new= -0.8579251236136358
# old= -0.8569538006611693
# new= -0.8583092353488898
# old= -0.8579251236136358
# new= -0.8584608683035415
# old= -0.8583092353488898
# new= -0.8585206860443508
# old= -0.8584608683035415
# new= -0.8585442771424041
# old= -0.8585206860443508
# new= -0.8585535800702984
# old= -0.8585442771424041
# new= -0.858557248437116
# old= -0.8585535800702984
# new= -0.8585586949376658
# old= -0.858557248437116
# new= -0.85855926531412
# old= -0.8585586949376658
# Converged in 13 iterations.
# The computed magnetization is: -0.858559
